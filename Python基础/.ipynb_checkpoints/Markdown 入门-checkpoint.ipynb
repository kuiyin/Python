# %% [markdown]
# 内容来自链接:[如何写md格式的文档](https://www.jianshu.com/p/f378e3f2e7e1)

# %% [markdown]
# # 一、标题
#
# # 1
# ## 2
# ### 3
# #### 4
# ##### 5
# ###### 6

# %% [markdown]
# # 二、字体
# ## 加粗
# 字体
# **字体**
#
# ## 斜体
# 字体
# *字体*
# _字体_
#
# ## 斜体加粗
# 字体
# ***字体***
# **_字体_**
#
# ## 删除线
# 字体
# ~~字体~~

# %% [markdown]
# # 三、引用
# 字体
# >字体
# >>字体
# >>>字体

# %% [markdown]
# # 四、分割线
# ---
# ***

# %% [markdown]
# # 五、图片
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# # 六、超链接
# [百度](http://baidu.com/)

# %% [markdown]
# # 七、列表
# ## 无序列表
# - 内容1
# + 内容2
# * 内容3
#
# 中间要带空格
#
# ## 有序列表
# 1. 内容1
# 2. 内容2
# 3. 内容3
#
# 数字加点,序号跟内容之间要有空格
#
# ## 列表嵌套
# 上一级和下一级之间敲三个空格即可
#
# - 一级无序
#    - 二级无序
#    - 二级无序
#       - 三级无序
#          - 四级无序
#             - 五级无序
#                - N级无序
#
# - 一级无序
#    - 二级无序
#    - 二级无序
#       - 三级无序
#
# 1. 一级有序
#    1. 二级有序
#    2. 二级有序
#       1. 三级有序
#       2. 三级有序
# 2. 一级有序
#    1. 二级有序
#    2. 二级有序
#       1. 三级有序

# %% [markdown]
# # 八、表格
#
# 表头|表头|表头
# ---|:--:|---:
# 内容|内容|内容
# 内容|内容|内容
#
# 第二行分割表头和内容。
# -有一个就行，为了对齐，多加了几个
# 文字默认居左
# -两边加：表示文字居中
# -右边加：表示文字居右
# 注：原生的语法两边都要用 | 包起来。此处省略
#
#
# | 表头 | 表头 | 表头 |
# | --- | --- | --- |
# |第一行|第一行|第一行|
# |第二行|第二行|第二行|
# |第三行|第三行|第三行|

# %% [markdown]
# # 九、代码
#
# ~单行代码~
#
# ~~~
#   代码块
# ~~~
# 你好
